# %%
import json
from pprint import pprint

with open('files.2017-06-26stomach_adenocarcinoma.json') as data_file:    
    data = json.load(data_file)

pprint(data)
# Out:
# [{'access': 'open',
#   'cases': [{'case_id': '75915370-0895-4933-8875-8a31c65c3d50',
#              'project': {'project_id': 'TCGA-STAD'}}],
#   'data_category': 'Transcriptome Profiling',
#   'data_format': 'TXT',
#   'file_name': '6a5dd3ed-c946-461c-a98e-c19e73ba3ef6.FPKM.txt.gz',
#   'file_size': 540565},
#  {'access': 'open',
#   'cases': [{'case_id': '8ce63594-bf4a-4b8d-9a48-49cb92b98ea9',
#              'project': {'project_id': 'TCGA-STAD'}}],
#   'data_category': 'Transcriptome Profiling',
#   'data_format': 'TXT',
#   'file_name': 'e15a011d-bba3-4807-bf48-dfa912d018af.htseq.counts.gz',
#   'file_size': 261657},
#  {'access': 'open',
#   'cases': [{'case_id': '5c68e3e4-58f7-4699-989d-80d2e4996794',
#              'project': {'project_id': 'TCGA-STAD'}}],
#   'data_category': 'Transcriptome Profiling',
#   'data_format': 'TXT',
#   'file_name': '32d19362-1f02-4584-b30a-758c1ba99c8a.FPKM.txt.gz',
#   'file_size': 559976},
#  {'access': 'open',
# ...
